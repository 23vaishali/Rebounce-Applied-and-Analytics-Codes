# %% [markdown]
# <a href="https://colab.research.google.com/github/23vaishali/Rebounce-Applied-and-Analytics-Codes/blob/main/Python%20101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting

# %% [markdown]
# **Problem -1. The Introduction card**

# %%
name = "Vaishali"
city ="Indore"
birth_year = 1988
age = 2026 -birth_year
print(f"Hi ,I am {name} from {city}.This year I turn {age}. " )
# Out:
# Hi ,I am Vaishali from Indore.This year I turn 38.

# %% [markdown]
# **Problem 2. The Currency Exchange**

# %%
rupees = 75000
one_rupees = 1.75
yen = rupees*one_rupees
print(f"Rs {rupees} converts to Yen {yen:.2f}")
# Out:
# Rs 75000 converts to Yen 131250.00
